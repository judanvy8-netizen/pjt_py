# %% [markdown]
# ### 문자형(문자열)
# * 파이썬에서 문자열(str)이란 문자열, 즉 문자의 집합을 의미한다.
# * 문자열은 작은/큰 따옴표 구분없이 사용
# * 여러줄은 문자열을 정의할 때는 큰 따옴표 3개 즉, """로 감싸서 정의한다

# %%
text = 'Hello'
text[0] = 'h' # 문자열(str)은 인덱싱을 통한 수정 불가
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 text = 'Hello'
# ----> 2 text[0] = 'h'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# 1. 문자열에 작은따옴표 포함하기

# %%
food = "Python's favorite food is perl"
food

# %% [markdown]
# 작은따옴표로 둘러싸면 'Python'이 문자열로 인식되어 구문 오류(SyntaxError)가 발생

# %%
food = 'Python's favorite food is perl'

# %% [markdown]
# 구문 오류(SyntaxError)가 발생

# %%
"Python is very easy." he says.

# %% [markdown]
# 2. 문자열에 큰따옴표 포함하기

# %%
say ='"Python is very easy." he says.'
say

# %% [markdown]
# 3. 역슬래시를 사용해서 작은따옴표와 큰따옴표를 문자열에 포함하기
#    역슬래시 --> 이스케이프 문자 --> ', "  출력할고자 할때 사용하는 문자열 제어 하는 특수문자

# %%
food = 'Python\'s favorite food is perl'
say = "\"Python is very easy.\" he says."
print(food)
print(say)

# %%
multiline = "Life is too short\nYou need python"
print(multiline)

# %% [markdown]
# 4. 연속된 작은따옴표 3개 또는 큰따옴표 3개 사용하기

# %%
multiline = '''
Life is too short
You need python
'''
print(multiline)
# Out:
# Life is too short
# You need python

# %%
multiline = """
Life is too short
You need python
"""
print(multiline)
# Out:
# Life is too short
# You need python

# %% [markdown]
# 문자열 연산하기

# %%
head = "Python"
tail = " is fun!"
head + tail
# Out:
# 'Python is fun!'

# %% [markdown]
# 문자열 곱하기

# %%
a = "python"
a * 2
# Out:
# 'pythonpython'

# %% [markdown]
# 문자열 곱하기 응용하기

# %%
# multistring.py

print("=" * 50)
print("My Program")
print("=" * 50)
# Out:
# ...
# My Program
# ...

# %% [markdown]
# 문자열 길이 구하기

# %%
a = "Life is too short"
len(a)
# Out:
# 17

# %% [markdown]
# ### 내장 함수 --> len()
# 전달된 객체의 길이, 즉 요소의 개수나 문자열의 글자 수를 정수 값으로 반환

# %% [markdown]
# ### 문자열 포매팅
# <table align="left" style="width:30%" border="1">
#     <caption><h3>문자열포맷코드</h3></caption>
#   <tr>
#     <th>코드</th>
#     <th>설명</th>
#   </tr>
#   <tr>
#     <td>%s</td>
#     <td>문자열 (String)</td>
#   </tr>
#   <tr>
#     <td>%c</td>
#     <td>한 개의 문자(Character)</td>
#   </tr>
#   <tr>
#     <td>%d</td>
#     <td>정수 (Integer)  d: decemal</td>
#   </tr>
#   <tr>
#     <td>%f</td>
#     <td>실수(float)</td>
#   </tr>
#   <tr>
#     <td>%o</td>
#     <td>8진수</td>
#   </tr>
#   <tr>
#     <td>%x</td>
#     <td>16진수</td>
#   </tr>
#   <tr>
#     <td>%%</td>
#     <td>퍼센트(%)문자</td>
#   </tr>
# </table>

# %% [markdown]
# ## 문자열 인덱싱과 슬라이싱
# 1. 문자열 인덱싱 : 문자열 '가르킨다',  0 ~ n-1 로 색인 부여, 문자열의 크기 n , 뒤로부터는 aos-1
# 2. 슬라이싱 : 문자열을 '잘라낸다'

# %%
a = "Life is too short, You need Python"
print(a[0])
print(a[12])
print(a[-1])
print(a[-2])
print(a[-34])
# Out:
# L
# s
# n
# o
# L

# %% [markdown]
# 문자열 슬라이싱

# %%
a = "Life is too short, You need Python"
b = a[0] + a[1] + a[2] + a[3]
b
# Out:
# 'Life'

# %%
a = "Life is too short, You need Python"
a[0:4]
# Out:
# 'Life'

# %%
a[0:3]
# Out:
# 'Lif'

# %%
a[0:5]
# Out:
# 'Life '

# %% [markdown]
# 슬라이싱으로 문자열 나누기

# %%
a = "20230331Rainy"
date = a[:8]
weather = a[8:]
print(date)
print(weather)
# Out:
# 20230331
# Rainy

# %%
a = "20230331Rainy"
year = a[:4]
day = a[4:8]
weather = a[8:]
print(year)
print(day)
print(weather)
# Out:
# 2023
# 0331
# Rainy

# %%
# %whos
# Out:
# Variable             Type      Data/Info
# ----------------------------------------
# a                    str       20230331Rainy
# b                    str       Life
# c                    str       \n문자열\n여러줄\n정의\n
# date                 str       20230331
# day                  str       0331
# food                 str       Python's favorite food is perl
# head                 str       Python
# multiline            str       \nLife is too short\nYou need python\n
# pydev_jupyter_vars   module    <module 'pydev_jupyter_va<...>\\pydev_jupyter_vars.py'>
# say                  str       "Python is very easy." he says.
# tail                 str        is fun!
# weather              str       Rainy
# year                 str       2023

# %% [markdown]
# ### 문자열 포매팅 이란?
# 정의 :  문자열안에 어떤 값을 삽입하는 방법

# %% [markdown]
# #### 문자열 포매팅 따라하기
# 1. 숫자 바로 대입

# %%
"I eat %d apples." % 3
# Out:
# 'I eat 3 apples.'

# %% [markdown]
# 2. 문자열 바로 대입

# %%
"I eat %s apples." % "five"
# Out:
# 'I eat five apples.'

# %% [markdown]
# 3. 숫자 값을 나타내는 변수로 대입하기

# %%
number = 3
"I eat %d apples." % number
# Out:
# 'I eat 3 apples.'

# %% [markdown]
# 4. 2개 이상의 값 넣기

# %%
number = 10
day = "three"
"I ate %d apples. so I was sick for %s days." % (number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %% [markdown]
# ### 문자열 포맷 코드 --> 교재 64 page

# %% [markdown]
# ### ★ %s 포맷코드는 어떤 형태의 값이든 변환해서 넣을수 있다

# %%
"I have %s apples" % 3
# Out:
# 'I have 3 apples'

# %%
"rate is %s" % 3.234
# Out:
# 'rate is 3.234'

# %% [markdown]
# 포매팅 연산자 %d와 % 를 같이 쓸때는 %% 를 쓴다

# %%
"Error is %d%%." % 98
# Out:
# 'Error is 98%.'

# %% [markdown]
# 포맷 코드와 숫자 함께 사용하기 --> 교재 66 ~ 67 참조

# %% [markdown]
# ### format 함수를 사용한 포매팅

# %% [markdown]
# 숫자 바로 대입하기

# %%
"I eat {0} apples".format(3)
# Out:
# 'I eat 3 apples'

# %% [markdown]
# 문자열 바로 대입하기

# %%
"I eat {0} apples".format("five")
# Out:
# 'I eat five apples'

# %% [markdown]
# 숫자 값을 가진 변수로 대입하기

# %%
number = 3
"I eat {0} apples".format(number)
# Out:
# 'I eat 3 apples'

# %% [markdown]
# 2개 이상의 값 넣기

# %%
number = 10
day = "three"
"I ate {0} apples. so I was sick for {1} days.".format(number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %% [markdown]
# 이름으로 넣기

# %%
"I ate {number} apples. so I was sick for {day} days.".format(number=10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %% [markdown]
# 인덱스와 이름을 혼용해서 넣기

# %%
"I ate {0} apples. so I was sick for {day} days.".format(10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %% [markdown]
# ### 포매코드 --> format( ) --> f 문자열 포매팅

# %% [markdown]
# ### f 문자열 포매팅

# %%
name = "홍길동"
age = 19
f'나의 이름은 {name}입니다. 나이는 {age}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 19입니다.'

# %% [markdown]
# 딕셔너리는 f 문자열 포매팅

# %%
d = {'name':'홍길동', 'age':30}
d
# Out:
# {'name': '홍길동', 'age': 30}

# %%
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %% [markdown]
# 정렬은 다음과 같이 할 수 있다.

# %%
 f'{"hi":<10}'  # 왼쪽 정렬
# Out:
# 'hi        '

# %%
f'{"hi":>10}'  # 오른쪽 정렬
# Out:
# '        hi'

# %%
f'{"hi":^10}'  # 가운데 정렬
# Out:
# '    hi    '

# %% [markdown]
# 공백 채우기는 다음과 같이 할 수 있다.

# %%
f'{"hi":=^10}'  # 가운데 정렬하고 '=' 문자로 공백 채우기
# Out:
# '====hi===='

# %%
f'{"hi":!<10}'  # 왼쪽 정렬하고 '!' 문자로 공백 채우기
# Out:
# 'hi!!!!!!!!'

# %% [markdown]
# 소수점은 다음과 같이 표현할 수 있다.

# %%
y = 3.42134234
f'{y:0.4f}'  # 소수점 4자리까지만 표현
# Out:
# '3.4213'

# %%
f'{y:10.4f}'  # 소수점 4자리까지 표현하고 총 자리수를 10으로 맞춤
# Out:
# '    3.4213'

# %% [markdown]
# f 문자열에서 {}를 문자 그대로 표시하려면 다음과 같이 2개를 동시에 사용해야 한다.

# %%
f'{{ and }}'
# Out:
# '{ and }'

# %% [markdown]
# ### 문자열 관련 함수들

# %%
a = "hobby"
a.count('b')
# Out:
# 2

# %%
",".join('abcd')
# Out:
# 'a,b,c,d'

# %%
a = "Life is too short"
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %% [markdown]
# 문자 개수 세기 - count

# %%
a = "hobby"
a.count('b')
# Out:
# 2

# %% [markdown]
# 위치 알려 주기 1 - find

# %%
a = "Python is the best choice"
a.find('b')
# Out:
# 14

# %% [markdown]
# 위치 알려 주기 2 - index

# %%
a = "Life is too short"
a.index('t')
# Out:
# 8

# %% [markdown]
# 문자열 삽입 - join

# %%
",".join('abcd')
# Out:
# 'a,b,c,d'

# %% [markdown]
# 소문자를 대문자로 바꾸기 - upper

# %%
a = "hi"
a.upper()
# Out:
# 'HI'

# %% [markdown]
# 대문자를 소문자로 바꾸기 - lower

# %%
a = "HI"
a.lower()
# Out:
# 'hi'

# %% [markdown]
# 왼쪽 공백 지우기 - lstrip

# %%
a = " hi "
a.lstrip()
# Out:
# 'hi '

# %% [markdown]
# 오른쪽 공백 지우기 - rstrip

# %%
a= " hi "
a.rstrip()
# Out:
# ' hi'

# %% [markdown]
# 양쪽 공백 지우기 - strip

# %%
a = " hi "
a.strip()
# Out:
# 'hi'

# %% [markdown]
# 문자열 바꾸기 - replace

# %%
a = "Life is too short"
a.replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %% [markdown]
# 문자열 나누기 - split

# %%
a = "Life is too short"
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
b = "a:b:c:d"
b.split(':')
# Out:
# ['a', 'b', 'c', 'd']

# %%
# %whos
# Out:
# Variable             Type      Data/Info
# ----------------------------------------
# a                    str       Life is too short
# age                  int       19
# b                    str       a:b:c:d
# c                    str       \n문자열\n여러줄\n정의\n
# d                    dict      n=2
# date                 str       20230331
# day                  str       three
# food                 str       Python's favorite food is perl
# head                 str       Python
# multiline            str       \nLife is too short\nYou need python\n
# name                 str       홍길동
# number               int       10
# pydev_jupyter_vars   module    <module 'pydev_jupyter_va<...>\\pydev_jupyter_vars.py'>
# say                  str       "Python is very easy." he says.
# tail                 str        is fun!
# weather              str       Rainy
# y                    float     3.42134234
# year                 str       2023

# %% [markdown]
# 문자열이 알파벳으로만 구성되어 있는지 확인하기 - isalpha

# %%
s = "Python"
s.isalpha()
# Out:
# True

# %%
s = "Python3"
s.isalpha()
# Out:
# False

# %%
s = "Hello World"
s.isalpha()
# Out:
# False

# %% [markdown]
# 문자열이 숫자로만 구성되어 있는지 확인하기 - isdigit

# %%
s = "12345"
s.isdigit()
# Out:
# True

# %%
s = "1234a"
s.isdigit()
# Out:
# False

# %%
s = "12 34"
s.isdigit()
# Out:
# False

# %% [markdown]
# 문자열이 특정 문자(열)로 시작하는지 확인하기 - startswith

# %%
s = "Life is too short"
s.endswith("short")
# Out:
# True

# %%
s.endswith("too")
# Out:
# False
