# %% [markdown]
# ### 명령 프롬프트를 사용
#
# * C:\doit\type 새파일.txt
# * 명령어 [인수1 인수2 ...]

# %% [markdown]
# 맥/리눅스에서는 type a.txt 대신 cat a.txt를 사용한다.

# %% [markdown]
# sys 모듈 사용하기

# %%
# sys1.py
import sys

args = sys.argv[1:]
for i in args:
    print(i)
